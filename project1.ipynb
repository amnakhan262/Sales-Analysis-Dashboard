# %%
import pandas as pd

df = pd.read_csv('Sample - Superstore.csv', encoding='latin1')
print(df.shape)
df.head(15)
# Out:
# (9994, 21)
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2        3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3        4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5        6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6        7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 7        8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8        9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 9       10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 10      11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 11      12  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 12      13  CA-2017-114412   4/15/2017   4/20/2017  Standard Class
# ...

# %%
df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
#df.groupby('Category')['Sales'].sum()

# %%
df.groupby('Region')['Profit'].sum().sort_values(ascending=False)
# Out:
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %%
df.groupby('Sales')['State'].sum().sort_values(ascending=False).head(10)
# Out:
# Sales
# 653.55                                   WisconsinWashington
# 25.06      WisconsinVirginiaMarylandVirginiaNew YorkVirginia
# 1099.96                                       WisconsinTexas
# 468.90                                     WisconsinNew York
# 149.97           WisconsinNebraskaCaliforniaVirginiaDelaware
# 373.08                                     WisconsinNebraska
# 185.58                                  WisconsinMississippi
# 125.99                                     WisconsinMichigan
# 245.88                                WisconsinMassachusetts
# 98.16                    WisconsinMarylandWashingtonKentucky
# Name: State, dtype: object

# %%
df.groupby('Sub-Category')['Profit'].sum().sort_values(ascending=False)
# Out:
# Sub-Category
# Copiers        55617.8249
# Phones         44515.7306
# Accessories    41936.6357
# Paper          34053.5693
# Binders        30221.7633
# Chairs         26590.1663
# Storage        21278.8264
# Appliances     18138.0054
# Furnishings    13059.1436
# Envelopes       6964.1767
# Art             6527.7870
# Labels          5546.2540
# Machines        3384.7569
# Fasteners        949.5182
# Supplies       -1189.0995
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
df.groupby('Segment')['Sales'].sum().sort_values(ascending=False)
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
df.to_csv('clean_superstore.csv', index=False)
print("File saved!")
# Out:
# File saved!

# %%
df.to_csv('clean_superstore_v2.csv', index=False)
print("Saved!")
# Out:
# Saved!
